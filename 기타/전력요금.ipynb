# %% [markdown]
# <a href="https://colab.research.google.com/github/Kim-Yiji/MID-Project/blob/%ED%99%A9%EB%AF%B8%EC%8A%B9/%EC%A0%84%EB%A0%A5%EC%9A%94%EA%B8%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
DATA_PATH = "/content/drive/MyDrive/LikeLion_Data/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 전력요금표

# %%
df = pd.read_csv(f"{DATA_PATH}주택용_전력요금표.csv", encoding="cp949")
df.head()
# Out:
#      연도  구분       기본요금 기준  기본요금     전력량요금 기준  전력량 요금
# 0  2013  저압   100kWh이하 사용   400  처음 100kWh까지    59.1
# 1  2013  저압  101～200kWh사용   890  다음 100kWh까지   122.6
# 2  2013  저압  201～300kWh사용  1560  다음 100kWh까지   183.0
# 3  2013  저압  301～400kWh사용  3750  다음 100kWh까지   273.2
# 4  2013  저압  401～500kWh사용  7110  다음 100kWh까지   406.7

# %%
df.rename(columns={"요금 (원)": "전력양 요금"})
# Out:
#       연도  구분        기본요금 기준   기본요금     전력량요금 기준  전력양 요금
# 0   2013  저압    100kWh이하 사용    400  처음 100kWh까지    59.1
# 1   2013  저압   101～200kWh사용    890  다음 100kWh까지   122.6
# 2   2013  저압   201～300kWh사용   1560  다음 100kWh까지   183.0
# 3   2013  저압   301～400kWh사용   3750  다음 100kWh까지   273.2
# 4   2013  저압   401～500kWh사용   7110  다음 100kWh까지   406.7
# 5   2013  저압    500kWh초과 사용  12600     500kWh초과   690.8
# 6   2013  고압    100kWh이하 사용    400  처음 100kWh까지    56.1
# 7   2013  고압   101～200kWh사용    710  다음 100kWh까지    96.3
# 8   2013  고압   201～300kWh사용   1230  다음 100kWh까지   143.4
# 9   2013  고압   301～400kWh사용   3090  다음 100kWh까지   209.9
# 10  2013  고압   401～500kWh사용   5900  다음 100kWh까지   317.1
# 11  2013  고압    500kWh초과 사용  10480     500kWh초과   559.5
# 12  2017  저압    200kWh이하 사용    910  처음 200kWh까지    93.3
# 13  2017  저압  201~400kWh 사용   1600  다음 200kWh까지   187.9
# 14  2017  저압    400kWh초과 사용   7300     400kWh초과   280.6
# 15  2017  고압    200kWh이하 사용    730  처음 200kWh까지    78.3
# ...

# %%
mask = df["연도"] < 2017

# %%
df = df.drop(df[mask].index)

# %%
df.to_csv(f"{DATA_PATH}전력요금표.csv")
