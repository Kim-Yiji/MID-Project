# %%
import matplotlib
from matplotlib import font_manager

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv

fontpaths = ["/usr/share/fonts/truetype/nanum/"]
font_files = font_manager.findSystemFonts(fontpaths=fontpaths)

for ff in font_files:
    font_manager.fontManager.addfont(ff)

matplotlib.rc('font', family="NanumGothic")
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/data/use_electricity2.csv'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(f'{DATA_PATH}', encoding='cp949')
df.head()
# Out:
#      시점 용도별(1)         항목           합계          1월          2월          3월  \
# 0  2017     합계  판매량 (MWh)  507746386.0  45196953.0  44422400.0  42558535.0
# 1  2017     합계    점유율 (%)        100.0       100.0       100.0       100.0
# 2  2017    가정용  판매량 (MWh)   66517357.0   5818186.0   5908998.0   5114346.0
# 3  2017    가정용    점유율 (%)         13.1        12.9        13.3        12.0
# 4  2017    공공용  판매량 (MWh)   23604528.0   2242732.0   2223466.0   2055510.0
#
#            4월          5월          6월          7월          8월          9월  \
# 0  40811060.0  38743894.0  39672664.0  43208492.0  45353733.0  42336101.0
# 1       100.0       100.0       100.0       100.0       100.0       100.0
# 2   5350759.0   4948471.0   5026250.0   5736415.0   6973292.0   5664935.0
# 3        13.1        12.8        12.7        13.3        15.4        13.4
# 4   1866996.0   1606449.0   1734025.0   2027381.0   2081653.0   1891449.0
#
#           10월         11월         12월
# ...

# %%
df = df.rename(columns={'용도별(1)': '용도'})
df.head()
# Out:
#      시점   용도         항목           합계          1월          2월          3월  \
# 0  2017   합계  판매량 (MWh)  507746386.0  45196953.0  44422400.0  42558535.0
# 1  2017   합계    점유율 (%)        100.0       100.0       100.0       100.0
# 2  2017  가정용  판매량 (MWh)   66517357.0   5818186.0   5908998.0   5114346.0
# 3  2017  가정용    점유율 (%)         13.1        12.9        13.3        12.0
# 4  2017  공공용  판매량 (MWh)   23604528.0   2242732.0   2223466.0   2055510.0
#
#            4월          5월          6월          7월          8월          9월  \
# 0  40811060.0  38743894.0  39672664.0  43208492.0  45353733.0  42336101.0
# 1       100.0       100.0       100.0       100.0       100.0       100.0
# 2   5350759.0   4948471.0   5026250.0   5736415.0   6973292.0   5664935.0
# 3        13.1        12.8        12.7        13.3        15.4        13.4
# 4   1866996.0   1606449.0   1734025.0   2027381.0   2081653.0   1891449.0
#
#           10월         11월         12월
# 0  38368804.0  41293174.0  45780576.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      98 non-null     int64
#  1   용도별(1)  98 non-null     object
#  2   항목      98 non-null     object
#  3   합계      98 non-null     float64
#  4   1월      98 non-null     float64
#  5   2월      98 non-null     float64
#  6   3월      98 non-null     float64
#  7   4월      98 non-null     float64
#  8   5월      98 non-null     float64
#  9   6월      98 non-null     float64
#  10  7월      98 non-null     float64
#  11  8월      98 non-null     float64
#  12  9월      98 non-null     float64
#  13  10월     98 non-null     float64
#  14  11월     98 non-null     float64
#  15  12월     98 non-null     float64
# dtypes: float64(13), int64(1), object(2)
# memory usage: 12.4+ KB

# %%
# 연도별 용도-합계에 대하여 월별 추출

tmp = df.loc[range(0, 98, 14)]
tmp = tmp.drop(tmp.columns[1:3], axis=1)
tmp
# Out:
#       시점           합계          1월          2월          3월          4월  \
# 0   2017  507746386.0  45196953.0  44422400.0  42558535.0  40811060.0
# 14  2018  526149160.0  48361740.0  46749816.0  42936450.0  42032551.0
# 28  2019  520498738.0  48644909.0  44353990.0  43089013.0  42440870.0
# 42  2020  509269715.0  46326914.0  44498866.0  42870787.0  40475291.0
# 56  2021  533430811.0  48755561.0  45187963.0  43074366.0  41899677.0
# 70  2022  547932742.0  49802219.0  47541471.0  45836806.0  43758280.0
# 84  2023  545965955.0  51240911.0  47874746.0  44094602.0  42300848.0
#
#             5월          6월          7월          8월          9월         10월  \
# 0   38743894.0  39672664.0  43208492.0  45353733.0  42336101.0  38368804.0
# 14  40530519.0  41045645.0  44029950.0  49532098.0  43729300.0  39977730.0
# 28  40708218.0  40620016.0  42966423.0  47558698.0  43649517.0  40623056.0
# 42  38327716.0  39752892.0  42067819.0  44599216.0  45110794.0  39065310.0
# ...

# %%
tmp.to_csv('use_electricity_month.csv', index=False, encoding='utf-8-sig')
