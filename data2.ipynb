# %%
import pandas as pd

x = pd.read_csv('data2/산업분류별 월별 전력사용량_20241011.csv')
x
# Out:
#        산업분류별 월별 전력사용량 ( 20241011 현재 ) Unnamed: 1     Unnamed: 2  \
# 0    시도 : 전체(시도), 시군구 : 전체(시 / 군 / 구)        NaN            NaN
# 1         기간 : 2024년 07 월 ~ 2024년 07월        NaN            NaN
# 2                                  년월         시구            시군구
# 3                              202407     전체(시도)  전체(시 / 군 / 구)
# 4                              202407     전체(시도)  전체(시 / 군 / 구)
# ..                                ...        ...            ...
# 390                            202407       충청북도             전체
# 391                            202407       충청북도             전체
# 392                            202407       충청북도             전체
# 393                            202407       충청북도             전체
# 394                            202407       충청북도             전체
#
#                    Unnamed: 3 Unnamed: 4      Unnamed: 5        Unnamed: 6  \
# 0                         NaN        NaN             NaN               NaN
# ...

# %%
data_2017_1_2017_6 = pd.read_csv('data2/산업분류별 월별 전력사용량_2017_1_2017_6.csv', header=3)
data_2017_7_2017_12 = pd.read_csv('data2/산업분류별 월별 전력사용량_2017_7_2017_12.csv', header=3)
data_2018_1_2019_6 = pd.read_csv('data2/산업분류별 월별 전력사용량_2018_1_2018_6.csv', header=3)
data_2018_7_2019_12 = pd.read_csv('data2/산업분류별 월별 전력사용량_2018_7_2018_12.csv', encoding='cp949', header=3)
data_2019_1_2019_6 = pd.read_csv('data2/산업분류별 월별 전력사용량_2019_1_2019_6.csv', encoding='cp949', header=3)
data_2019_7_2019_12 = pd.read_csv('data2/산업분류별 월별 전력사용량_2019_7_2019_12.csv', encoding='cp949', header=3)
data_2020_1_2020_6 = pd.read_csv('data2/산업분류별 월별 전력사용량_2020_1_2020_6.csv', header=3)
data_2020_7_2020_12 = pd.read_csv('data2/산업분류별 월별 전력사용량_2020_7_2020_12.csv', header=3)
data_2021_1_2021_6 = pd.read_csv('data2/산업분류별 월별 전력사용량_2021_1_2021_6.csv', header=3)
data_2021_7_2021_12 = pd.read_csv('data2/산업분류별 월별 전력사용량_2021_07_2021_12.csv', header=3)
data_2022_1_2022_6 = pd.read_csv('data2/산업분류별 월별 전력사용량_2022_01_2022_06.csv', header=3)
data_2022_7_2022_12 = pd.read_csv('data2/산업분류별 월별 전력사용량_2022_07_2022_12.csv', header=3)

# %%
data_2017_1_2017_6
# Out:
#           년월      시구            시군구                계약구분   고객호수(호)  \
# 0     201701  전체(시도)  전체(시 / 군 / 구)     가구내고용,미분류자가소비생산      528
# 1     201701  전체(시도)  전체(시 / 군 / 구)                건설업    70,529
# 2     201701  전체(시도)  전체(시 / 군 / 구)  공공행정, 국방 및 사회보장 행정   34,768
# 3     201701  전체(시도)  전체(시 / 군 / 구)                 광업     4,614
# 4     201701  전체(시도)  전체(시 / 군 / 구)             교육 서비스업   69,866
# ...      ...     ...            ...                 ...       ...
# 2344  201706    충청북도             전체                제조업     9,933
# 2345  201706    충청북도             전체     출판영상,방송통신정보서비스업    7,972
# 2346  201706    충청북도             전체      하수폐기처리원료재생환경복원    1,788
# 2347  201706    충청북도             전체     협회단체,수리기타개인서비스업    9,215
# 2348  201706    충청북도             전체                  합계  248,936
#
#             사용량(kWh)           전기요금(원) 평균판매단가(원/kWh)
# 0           571,710        86,427,025         151.2
# 1       367,547,850    49,248,531,866         134.0
# ...

# %%
data_2019_1_2019_6
# Out:
#           년월      시구            시군구                      계약구분   고객호수(호)  \
# 0     201901  전체(시도)  전체(시 / 군 / 구)  가구내고용활동및달리분류되지않은자가소비생산활동      484
# 1     201901  전체(시도)  전체(시 / 군 / 구)                       건설업   75,778
# 2     201901  전체(시도)  전체(시 / 군 / 구)       공공 행정, 국방 및 사회보장 행정   39,053
# 3     201901  전체(시도)  전체(시 / 군 / 구)                        광업    3,633
# 4     201901  전체(시도)  전체(시 / 군 / 구)                   교육 서비스업   69,826
# ...      ...     ...            ...                       ...       ...
# 2362  201906    충청북도             전체  협회 및 단체, 수리 및 기타 개인 서비스업    9,068
# 2363  201906    충청북도             전체                        합계  274,187
# 2364  201906    황해북도             전체                      부동산업        9
# 2365  201906    황해북도             전체   수도, 하수 및 폐기물 처리, 원료 재생업    5호미만제거
# 2366  201906    황해북도             전체                        합계        9
#
#             사용량(kWh)           전기요금(원) 평균판매단가(원/kWh)
# 0           530,866        78,262,080         147.4
# ...

# %%
data_2022_1_2022_6
# Out:
#           년월      시구            시군구                계약구분   고객호수(호)  \
# 0     202201  전체(시도)  전체(시 / 군 / 구)     가구내고용,미분류자가소비생산      420
# 1     202201  전체(시도)  전체(시 / 군 / 구)                건설업    85,971
# 2     202201  전체(시도)  전체(시 / 군 / 구)  공공행정, 국방 및 사회보장 행정   47,988
# 3     202201  전체(시도)  전체(시 / 군 / 구)                 광업     3,789
# 4     202201  전체(시도)  전체(시 / 군 / 구)             교육 서비스업   72,253
# ...      ...     ...            ...                 ...       ...
# 2355  202206    충청북도             전체                제조업    13,312
# 2356  202206    충청북도             전체     출판영상,방송통신정보서비스업   10,263
# 2357  202206    충청북도             전체      하수폐기처리원료재생환경복원    1,997
# 2358  202206    충청북도             전체     협회단체,수리기타개인서비스업    9,066
# 2359  202206    충청북도             전체                  합계  299,716
#
#             사용량(kWh)           전기요금(원) 평균판매단가(원/kWh)
# 0           437,002        67,479,235         154.4
# 1       463,385,009    61,401,994,546         132.5
# ...

# %%
data_2020_7_2020_12
# Out:
#           년월      시구            시군구                      계약구분   고객호수(호)  \
# 0     202007  전체(시도)  전체(시 / 군 / 구)  가구내고용활동및달리분류되지않은자가소비생산활동      450
# 1     202007  전체(시도)  전체(시 / 군 / 구)                       건설업   79,443
# 2     202007  전체(시도)  전체(시 / 군 / 구)       공공 행정, 국방 및 사회보장 행정   43,948
# 3     202007  전체(시도)  전체(시 / 군 / 구)                        광업    3,556
# 4     202007  전체(시도)  전체(시 / 군 / 구)                   교육 서비스업   69,221
# ...      ...     ...            ...                       ...       ...
# 2362  202012    충청북도             전체  협회 및 단체, 수리 및 기타 개인 서비스업    9,073
# 2363  202012    충청북도             전체                        합계  286,311
# 2364  202012    황해북도             전체                      부동산업        9
# 2365  202012    황해북도             전체   수도, 하수 및 폐기물 처리, 원료 재생업    5호미만제거
# 2366  202012    황해북도             전체                        합계        9
#
#             사용량(kWh)           전기요금(원) 평균판매단가(원/kWh)
# 0           376,237        67,128,907         178.4
# ...

# %%
data = pd.concat([data_2017_1_2017_6, data_2017_7_2017_12, data_2018_1_2019_6, data_2018_7_2019_12, data_2019_1_2019_6, data_2019_7_2019_12, data_2020_1_2020_6, data_2020_7_2020_12, data_2021_1_2021_6, data_2021_7_2021_12, data_2022_1_2022_6, data_2022_7_2022_12])
data
# Out:
#           년월      시구            시군구                계약구분   고객호수(호)  \
# 0     201701  전체(시도)  전체(시 / 군 / 구)     가구내고용,미분류자가소비생산      528
# 1     201701  전체(시도)  전체(시 / 군 / 구)                건설업    70,529
# 2     201701  전체(시도)  전체(시 / 군 / 구)  공공행정, 국방 및 사회보장 행정   34,768
# 3     201701  전체(시도)  전체(시 / 군 / 구)                 광업     4,614
# 4     201701  전체(시도)  전체(시 / 군 / 구)             교육 서비스업   69,866
# ...      ...     ...            ...                 ...       ...
# 2340  202212    충청북도             전체                제조업    13,495
# 2341  202212    충청북도             전체     출판영상,방송통신정보서비스업   10,528
# 2342  202212    충청북도             전체      하수폐기처리원료재생환경복원    2,014
# 2343  202212    충청북도             전체     협회단체,수리기타개인서비스업    9,077
# 2344  202212    충청북도             전체                  합계  305,476
#
#             사용량(kWh)           전기요금(원) 평균판매단가(원/kWh)
# 0           571,710        86,427,025         151.2
# 1       367,547,850    49,248,531,866         134.0
# ...

# %%
data.to_csv('data2/산업분류별 월별 전력사용량_2017_2022.csv', index = False)
x = pd.read_csv('data2/산업분류별 월별 전력사용량_2017_2022.csv')
x
# Out:
#            년월      시구            시군구                계약구분   고객호수(호)  \
# 0      201701  전체(시도)  전체(시 / 군 / 구)     가구내고용,미분류자가소비생산      528
# 1      201701  전체(시도)  전체(시 / 군 / 구)                건설업    70,529
# 2      201701  전체(시도)  전체(시 / 군 / 구)  공공행정, 국방 및 사회보장 행정   34,768
# 3      201701  전체(시도)  전체(시 / 군 / 구)                 광업     4,614
# 4      201701  전체(시도)  전체(시 / 군 / 구)             교육 서비스업   69,866
# ...       ...     ...            ...                 ...       ...
# 28303  202212    충청북도             전체                제조업    13,495
# 28304  202212    충청북도             전체     출판영상,방송통신정보서비스업   10,528
# 28305  202212    충청북도             전체      하수폐기처리원료재생환경복원    2,014
# 28306  202212    충청북도             전체     협회단체,수리기타개인서비스업    9,077
# 28307  202212    충청북도             전체                  합계  305,476
#
#              사용량(kWh)           전기요금(원) 평균판매단가(원/kWh)
# 0            571,710        86,427,025         151.2
# 1        367,547,850    49,248,531,866         134.0
# ...

# %%
data.groupby('시구').count()
# Out:
#            년월   시군구  계약구분  고객호수(호)  사용량(kWh)  전기요금(원)  평균판매단가(원/kWh)
# 시구
# 강원도      1584  1584  1584     1584      1584     1584           1584
# 경기도      1587  1587  1587     1587      1587     1587           1587
# 경상남도     1584  1584  1584     1584      1584     1584           1584
# 경상북도     1584  1584  1584     1584      1584     1584           1584
# 광주광역시    1584  1584  1584     1584      1584     1584           1584
# 대구광역시    1584  1584  1584     1584      1584     1584           1584
# 대전광역시    1562  1562  1562     1562      1562     1562           1562
# 미분류        10    10    10       10        10       10             10
# 부산광역시    1584  1584  1584     1584      1584     1584           1584
# 서울특별시    1584  1584  1584     1584      1584     1584           1584
# 세종특별자치시  1512  1512  1512     1512      1512     1512           1512
# 시구         12    12    12       12        12       12             12
# 울산광역시    1512  1512  1512     1512      1512     1512           1512
# ...
